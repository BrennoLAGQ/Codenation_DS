# %% [markdown]
# ## Importação de biblioteca e dados

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('desafio1.csv')

# %%
submission = pd.read_json('submission.json')

# %% [markdown]
# ## EDA

# %%
submission
# Out:
#                SC  RS  PR
# moda            0   0   0
# mediana         0   0   0
# media           0   0   0
# desvio_padrao   0   0   0

# %%
df.head(10)
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
# 5          6  db5cf32c3fbc7c5d8f8313afca1d099de6dc055f
# 6          7  8f3cc64a0a84bab38fefb030f09757d0cbf03bb2
# 7          8  6704b822c203e2dda9f225dfc4f1bed2ae9044e6
# 8          9  35f41954a87f722a3960e5fa8ce898a09398a564
# 9         10  f110be36fc6171a7da472b9cbac8698df880aac6
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# ...

# %%
df.describe(include='all')
# Out:
#           RowNumber                                        id  \
# count   7000.000000                                      7000
# unique          NaN                                      7000
# top             NaN  f4054ccc23b80b236c365a7e51c527f66e9ed45e
# freq            NaN                                         1
# mean    3500.500000                                       NaN
# std     2020.870275                                       NaN
# min        1.000000                                       NaN
# 25%     1750.750000                                       NaN
# 50%     3500.500000                                       NaN
# 75%     5250.250000                                       NaN
# max     7000.000000                                       NaN
#
#                                        sobrenome  pontuacao_credito  \
# count                                       7000        7000.000000
# unique                                      2448                NaN
# ...

# %%
aux = pd.DataFrame({'columns': df.columns,
                    'type': df.dtypes,
                    'percentual faltante': df.isna().sum()/df.shape[0]})
aux
# Out:
#                                            columns     type  \
# RowNumber                                RowNumber    int64
# id                                              id   object
# sobrenome                                sobrenome   object
# pontuacao_credito                pontuacao_credito    int64
# estado_residencia                estado_residencia   object
# genero                                      genero   object
# idade                                        idade    int64
# nivel_estabilidade              nivel_estabilidade    int64
# saldo_conta                            saldo_conta  float64
# numero_produtos                    numero_produtos    int64
# possui_cartao_de_credito  possui_cartao_de_credito    int64
# membro_ativo                          membro_ativo    int64
#
#                           percentual faltante
# RowNumber                                 0.0
# id                                        0.0
# ...

# %%
df.shape
# Out:
# (7000, 12)

# %%
df.groupby('estado_residencia')['pontuacao_credito'].describe()
# Out:
#                     count        mean        std    min    25%    50%    75%  \
# estado_residencia
# PR                 1731.0  648.961294  98.607186  350.0  581.0  650.0  719.5
# RS                 1750.0  651.105143  95.136598  350.0  585.0  650.0  717.0
# SC                 3519.0  649.537653  97.233493  359.0  581.0  653.0  717.0
#
#                      max
# estado_residencia
# PR                 850.0
# RS                 850.0
# SC                 850.0

# %%
df
# Out:
#       RowNumber                                        id  \
# 0             1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1             2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2             3  774bc378f787438c9c7594e536787d07a097a54b
# 3             4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4             5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
# ...         ...                                       ...
# 6995       6996  3e607c788c09d6e1f99cc50575e471fee41a322a
# 6996       6997  2afdb40334e1bef3451f3db02b12c255c7a9ff57
# 6997       6998  6a0589e36c12f95a8d3678b460519ed654fe0a3e
# 6998       6999  c042de909a1fb157765c84c3278d8e6500807367
# 6999       7000  cdce83890ea1d7b64b2caaaea76f499cb5dfe684
#
#                                      sobrenome  pontuacao_credito  \
# 0     6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1     48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2     f2b29d5d934de615812b697132e767dea0f1e9e2                502
# ...

# %%
submission
# Out:
#                SC  RS  PR
# moda            0   0   0
# mediana         0   0   0
# media           0   0   0
# desvio_padrao   0   0   0

# %%
sc_list = []
sc_moda = df.query('estado_residencia == "SC"')['pontuacao_credito'].value_counts().index[0]
sc_median = int(df.query('estado_residencia == "SC"')['pontuacao_credito'].sort_values().median())
sc_media = df.query('estado_residencia == "SC"')['pontuacao_credito'].mean()
sc_dp = df.query('estado_residencia == "SC"')['pontuacao_credito'].std()

# %%
sc_list.append(sc_moda)
sc_list.append(sc_median)
sc_list.append(sc_media)
sc_list.append(sc_dp)
sc_list
# Out:
# [850, 653, 649.5376527422563, 97.233492793433]

# %%
submission['SC'] = sc_list
submission['RS'] = rs_list
submission['PR'] = pr_list
submission
# Out:
#                        SC          RS          PR
# moda           850.000000  850.000000  850.000000
# mediana        653.000000  650.000000  650.000000
# media          649.537653  651.105143  648.961294
# desvio_padrao   97.233493   95.136598   98.607186

# %%
rs_list = []
rs_list.append(df.query('estado_residencia == "RS"')['pontuacao_credito'].value_counts().index[0])
rs_list.append(df.query('estado_residencia == "RS"')['pontuacao_credito'].sort_values().median())
rs_list.append(df.query('estado_residencia == "RS"')['pontuacao_credito'].mean())
rs_list.append(df.query('estado_residencia == "RS"')['pontuacao_credito'].std())
rs_list
# Out:
# [850, 650.0, 651.1051428571428, 95.13659841383574]

# %%
pr_list = []
pr_list.append(df.query('estado_residencia == "PR"')['pontuacao_credito'].value_counts().index[0])
pr_list.append(df.query('estado_residencia == "PR"')['pontuacao_credito'].sort_values().median())
pr_list.append(df.query('estado_residencia == "PR"')['pontuacao_credito'].mean())
pr_list.append(df.query('estado_residencia == "PR"')['pontuacao_credito'].std())
pr_list
# Out:
# [850, 650.0, 648.9612940496822, 98.60718591309758]

# %%
submission.to_json('submission.json')
